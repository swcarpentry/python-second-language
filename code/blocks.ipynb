# %%
from ipythonblocks import BlockGrid

w = 15
h = 15
grid = BlockGrid(w, h, block_size=15)

for block in grid:
    block.red = 255 * (w - block.col) / w
    block.green = 255 * (h - block.row) / h
    block.blue = 255 * block.col / w

grid.show()
# Out:
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocks6bd1aa4c-7630-4058-85ff-07825a86a21a td {border: 1px solid white;}</style><table id="blocks6bd1aa4c-7630-4058-85ff-07825a86a21a" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (255, 255, 0)" style="width: 15px; height: 15px;background-color: rgb(255, 255, 0);"></td><td title="Index: [0, 1]&#10;Color: (238, 255, 17)" style="width: 15px; height: 15px;background-color: rgb(238, 255, 17);"></td><td title="Index: [0, 2]&#10;Color: (221, 255, 34)" style="width: 15px; height: 15px;background-color: rgb(221, 255, 34);"></td><td title="Index: [0, 3]&#10;Color: (204, 255, 51)" style="width: 15px; height: 15px;background-color: rgb(204, 255, 51);"></td><td title="Index: [0, 4]&#10;Color: (187, 255, 68)" style="width: 15px; height: 15px;background-color: rgb(187, 255, 68);"></td><td title="Index: [0, 5]&#10;Color: (170, 255, 85)" style="width: 15px; height: 
# ...
