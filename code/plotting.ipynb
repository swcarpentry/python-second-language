# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
dataValues = [1,2,3,5,7,11]
plt.plot(dataValues)
plt.show()

# %%
dataValues = [1,2,3,5,7,11]
dataIndex = [0.2,0.4,0.6,0.8,1,1.2]
plt.plot(dataIndex, dataValues)
plt.show()

# %%
dataValues = [1,2,3,5,7,11]
dataIndex = [0.2,0.4,0.6,0.8,1,1.2]
plt.plot(dataValues, dataIndex)
plt.show()

# %%
dataValues = [1,2,3,5,7,11]
dataIndex = [0.2,0.4,0.6,0.8,1,1.2]
plt.plot(dataIndex, dataValues)
plt.title('First Plot')
plt.ylabel('data values')
plt.xlabel('data indices')
plt.show()

# %%
import pandas as pd
daily_prices = pd.read_csv("../data/goog.csv")
print (daily_prices)
# Out:
#           Date        Open        High         Low       Close   Volume  \
# 0   2016-11-22  772.630005  776.960022  767.000000  768.270020  1591800
# 1   2016-11-21  762.609985  769.700012  760.599976  769.200012  1323000
# 2   2016-11-18  771.369995  775.000000  760.000000  760.539978  1526200
# 3   2016-11-17  766.919983  772.700012  764.229980  771.229980  1287000
# 4   2016-11-16  755.200012  766.359985  750.510010  764.479980  1465200
# 5   2016-11-15  746.969971  764.416016  746.969971  758.489990  2341200
# 6   2016-11-14  755.599976  757.849976  727.539978  736.080017  3631700
# 7   2016-11-11  756.539978  760.780029  750.380005  754.020020  2394000
# 8   2016-11-10  791.169983  791.169983  752.179993  762.559998  4740100
# 9   2016-11-09  779.940002  791.226990  771.669983  785.309998  2602700
# 10  2016-11-08  783.400024  795.632996  780.190002  790.510010  1350800
# 11  2016-11-07  774.500000  785.190002  772.549988  782.520020  1585100
# 12  2016-11-04  750.659973  770.359985  750.560974  762.020020  2134800
# 13  2016-11-03  767.250000  769.950012  759.030029  762.130005  1943200
# 14  2016-11-02  778.200012  781.650024  763.450012  768.700012  1872400
# 15  2016-11-01  782.890015  789.489990  775.539978  783.609985  2406400
#
#      Adj Close
# 0   768.270020
# 1   769.200012
# 2   760.539978
# 3   771.229980
# 4   764.479980
# 5   758.489990
# 6   736.080017
# 7   754.020020
# 8   762.559998
# 9   785.309998
# 10  790.510010
# 11  782.520020
# 12  762.020020
# 13  762.130005
# 14  768.700012
# 15  783.609985

# %%
plt.plot(daily_prices["Open"])
plt.title('Google stock between 11/01/2016 and 11/22/2016')
plt.ylabel('Price')
plt.xlabel('Date')
plt.xticks(range(0,16), daily_prices["Date"])
plt.show()

# %%
plt.plot(daily_prices["Open"])
plt.title('Google stock between 11/01/2016 and 11/22/2016')
plt.ylabel('Price')
plt.xlabel('Date')
plt.xticks(range(0,16), daily_prices["Date"], rotation='vertical')
plt.show()

# %%
plt.scatter(range(0,16), daily_prices["Open"])
plt.title('Google stock between 11/01/2016 and 11/22/2016')
plt.ylabel('Price')
plt.xlabel('Date')
plt.xticks(range(0,16), daily_prices["Date"], rotation='vertical')
plt.show()

# %%
plt.scatter(range(0,16), daily_prices["Open"])
plt.scatter(range(0,16), daily_prices["Close"])
plt.title('Google stock between 11/01/2016 and 11/22/2016')
plt.ylabel('Price')
plt.xlabel('Date')
plt.xticks(range(0,16), daily_prices["Date"], rotation='vertical')
plt.show()

# %%
plt.scatter(range(0,16), daily_prices["Open"], color="red")
plt.scatter(range(0,16), daily_prices["Close"], color="blue")
plt.title('Google stock between 11/01/2016 and 11/22/2016')
plt.ylabel('Price')
plt.xlabel('Date')
plt.xticks(range(0,16), daily_prices["Date"], rotation='vertical')
plt.show()

# %%
plt.scatter(range(0,16), daily_prices["Open"], color="red", label="Open")
plt.scatter(range(0,16), daily_prices["Close"], color="blue", label="Close")
plt.title('Google stock between 11/01/2016 and 11/22/2016')
plt.ylabel('Price')
plt.xlabel('Date')
plt.xticks(range(0,16), daily_prices["Date"], rotation='vertical')
plt.legend(loc='upper right')
plt.show()

# %%
plt.scatter(range(0,16), daily_prices["Open"], color="red", label="Open")
plt.scatter(range(0,16), daily_prices["Close"], color="blue", label="Close")
plt.title('Google stock between 11/01/2016 and 11/22/2016')
plt.ylabel('Price')
plt.xlabel('Date')
plt.xticks(range(0,16), daily_prices["Date"], rotation='vertical')
plt.legend(loc='upper left', scatterpoints = 1)
plt.show()
